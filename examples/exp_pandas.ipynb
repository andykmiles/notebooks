# %%
"""from IPython.display import display, HTML
import chart_studio.plotly as py  # pip install & replace plotly.plotly
import plotly.graph_objs as go
import plotly
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf # pip install
cf.set_config_file(offline=True)"""

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math


pd.set_option("display.max_columns", None)
pd.options.display.width = 0

# %%
hbk = pd.read_csv("hotel_bookings.csv")

# %%
hbk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29674 entries, 0 to 29673
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           29674 non-null  object
#  1   is_canceled                     29674 non-null  int64
#  2   lead_time                       29674 non-null  int64
#  3   arrival_date_year               29674 non-null  int64
#  4   arrival_date_month              29674 non-null  object
#  5   arrival_date_week_number        29674 non-null  int64
#  6   arrival_date_day_of_month       29674 non-null  int64
#  7   stays_in_weekend_nights         29674 non-null  int64
#  8   stays_in_week_nights            29674 non-null  int64
#  9   adults                          29674 non-null  int64
#  10  children                        29674 non-null  int64
#  11  babies                          29674 non-null  int64
# ...

# %%
hbk.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  29674.000000  29674.000000       29674.000000
# mean       0.374503     97.709139        2015.880164
# std        0.484002     99.453338           0.652820
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     12.000000        2015.000000
# 50%        0.000000     65.000000        2016.000000
# 75%        1.000000    162.000000        2016.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              29674.000000               29674.000000
# mean                  28.380164                  15.836962
# std                   13.401713                   8.876748
# min                    1.000000                   1.000000
# 25%                   18.000000                   8.000000
# 50%                   30.000000                  16.000000
# 75%                   39.000000                  24.000000
# ...

# %%
print(hbk["country"])
# Out:
# 0        PRT
# 1        PRT
# 2        GBR
# 3        GBR
# 4        GBR
#         ...
# 29669    DEU
# 29670    DEU
# 29671    FRA
# 29672    GBR
# 29673    MDV
# Name: country, Length: 29674, dtype: object

# %%
hbk
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 29669  Resort Hotel            0         43               2016
# 29670  Resort Hotel            0         43               2016
# 29671  Resort Hotel            0        162               2016
# 29672  Resort Hotel            0          3               2016
# 29673  Resort Hotel            0          1               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
null_data = hbk[hbk.isnull().any(axis=1)]
null_data

# %%
hbk.isnull().any(axis=1).sum()

# %%
hbk.columns[hbk.isnull().any()]

# %%
week_groups = hbk.groupby([hbk['arrival_date_year'],hbk['arrival_date_week_number']]
                          )['hotel'].count()
week_groups

# %%
week_groups.iplot(kind='line',legend=None)

# %%
week_means = hbk.groupby([hbk['arrival_date_year'],hbk['arrival_date_week_number']]
                          )['days_in_waiting_list'].mean()
week_means

# %%
week_means.iplot(kind='bar',legend=None, title="My new chart")

# %%
hbk.groupby("is_repeated_guest")['previous_cancellations'].mean().iplot(kind='bar')

# %%
arrivals = hbk[['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_week_number']]
arrivals

# %%
hotel_values = arrivals.hotel.unique()
hotel_values

# %%
graph_df = arrivals.groupby(by="arrival_date_week_number").mean()["lead_time"]
graph_df.iplot(kind='scatter', title="Andy's example")

# %%
week_groups.plot(kind='line',legend=None, xlim=None, ylim=(300,600))

# %%
week_groups

# %%
g = arrivals.groupby('arrival_date_week_number')
arrivals = hbk[['arrival_date_year', 'arrival_date_week_number']]
arrivals.sort_values(['arrival_date_year', 'arrival_date_week_number'])
arrivals['sequence']=arrivals.groupby('arrival_date_year').cumcount()

# %%
week_groups

# %%
g = arrivals.groupby('arrival_date_week_number')

# %%
g.head()
