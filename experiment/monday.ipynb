# %%
from IPython.display import display, HTML
import chart_studio.plotly as py  # pip install & replace plotly.plotly
import plotly.graph_objs as go
import plotly
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf # pip install
cf.set_config_file(offline=True)

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math


pd.set_option("display.max_columns", None)
pd.options.display.width = 0
pd.set_option('display.max_rows', 20)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
udq = pd.read_csv("user_data_quant4.csv")
udq
# Out:
#       user_id   timestamp     date  anxiety  satisfaction  worthwhile  happy
# 0         204  1593195093  6/26/20        1             8           6      7
# 1         204  1593370688  6/28/20        1             7           8      9
# 2         204  1593454064  6/29/20        1             8           7      9
# 3         204  1593540110  6/30/20        1             8           8      9
# 4         204  1593627398   7/1/20        1             8           6      5
# ...       ...         ...      ...      ...           ...         ...    ...
# 1301     9906  1594317811   7/9/20        3             7           7      8
# 1302     9906  1594410546  7/10/20        3             7           7      8
# 1303     9906  1594491542  7/11/20        3             7           7      8
# 1304     9906  1594577042  7/12/20        3             7           7      8
# 1305     9906  1594663506  7/13/20        4             8           7      7
#
# [1306 rows x 7 columns]

# %%
udq.sort_values(['user_id', 'timestamp'])
# Out:
#       user_id   timestamp     date  anxiety  satisfaction  worthwhile  happy
# 0         204  1593195093  6/26/20        1             8           6      7
# 1         204  1593370688  6/28/20        1             7           8      9
# 2         204  1593454064  6/29/20        1             8           7      9
# 3         204  1593540110  6/30/20        1             8           8      9
# 4         204  1593627398   7/1/20        1             8           6      5
# ...       ...         ...      ...      ...           ...         ...    ...
# 1301     9906  1594317811   7/9/20        3             7           7      8
# 1302     9906  1594410546  7/10/20        3             7           7      8
# 1303     9906  1594491542  7/11/20        3             7           7      8
# 1304     9906  1594577042  7/12/20        3             7           7      8
# 1305     9906  1594663506  7/13/20        4             8           7      7
#
# [1306 rows x 7 columns]

# %%
udq['sequence']=udq.groupby('user_id').cumcount()+1

# %%
#pd.set_option('display.max_rows', None)
pd.set_option('display.max_rows', 10)
udq
# Out:
#       user_id   timestamp     date  anxiety  satisfaction  worthwhile  happy  \
# 0         204  1593195093  6/26/20        1             8           6      7
# 1         204  1593370688  6/28/20        1             7           8      9
# 2         204  1593454064  6/29/20        1             8           7      9
# 3         204  1593540110  6/30/20        1             8           8      9
# 4         204  1593627398   7/1/20        1             8           6      5
# ...       ...         ...      ...      ...           ...         ...    ...
# 1301     9906  1594317811   7/9/20        3             7           7      8
# 1302     9906  1594410546  7/10/20        3             7           7      8
# 1303     9906  1594491542  7/11/20        3             7           7      8
# 1304     9906  1594577042  7/12/20        3             7           7      8
# 1305     9906  1594663506  7/13/20        4             8           7      7
#
#       sequence
# 0            1
# ...

# %%
pd.set_option('display.max_rows', 20)

# %%
ao = udq.groupby([udq['user_id']]
                          )['anxiety'].mean()

# %%
ao.plot.bar()
plt.ylim(-1,10)
plt.xlim(0, 10)
plt.show()

# %%
plt.show()

# %%
df['Total Bags'].plot()
df['Total Bags'].rolling(window=3).mean().plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a4a3123a8eba> in <module>
# ----> 1 df['Total Bags'].plot()
#       2 df['Total Bags'].rolling(window=3).mean().plot()
#
# NameError: name 'df' is not defined
